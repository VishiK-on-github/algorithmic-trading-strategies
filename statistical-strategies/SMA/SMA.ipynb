# %% [markdown]
# ## Simple Moving Average

# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# %%
data = pd.read_csv(filepath_or_buffer='../../resources/intraday.csv', parse_dates=['time'], index_col='time')

# %%
data.head(10)
# Out:
#                Close
# time
# 2009-12-31  1.432706
# 2010-01-01  1.438994
# 2010-01-04  1.442398
# 2010-01-05  1.436596
# 2010-01-06  1.440403
# 2010-01-07  1.431803
# 2010-01-08  1.441109
# 2010-01-11  1.451126
# 2010-01-12  1.447660
# 2010-01-13  1.452391

# %%
data.tail(10)
# Out:
#                Close
# time
# 2021-12-20  1.124354
# 2021-12-21  1.127752
# 2021-12-22  1.128757
# 2021-12-23  1.132888
# 2021-12-24  1.132734
# 2021-12-27  1.132426
# 2021-12-28  1.133003
# 2021-12-29  1.131478
# 2021-12-30  1.136015
# 2021-12-31  1.132503

# %%
data.Close.to_frame()
# Out:
#                Close
# time
# 2009-12-31  1.432706
# 2010-01-01  1.438994
# 2010-01-04  1.442398
# 2010-01-05  1.436596
# 2010-01-06  1.440403
# ...              ...
# 2021-12-27  1.132426
# 2021-12-28  1.133003
# 2021-12-29  1.131478
# 2021-12-30  1.136015
# 2021-12-31  1.132503
#
# [3127 rows x 1 columns]

# %%
data = data.Close.to_frame()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.Close, name='Close'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
data['SMA50'] = data.rolling(window=50, min_periods=50).mean()

# %%
data['SMA200'] = data.Close.rolling(window=200, min_periods=200).mean()

# %%
data
# Out:
#                Close     SMA50    SMA200
# time
# 2009-12-31  1.432706       NaN       NaN
# 2010-01-01  1.438994       NaN       NaN
# 2010-01-04  1.442398       NaN       NaN
# 2010-01-05  1.436596       NaN       NaN
# 2010-01-06  1.440403       NaN       NaN
# ...              ...       ...       ...
# 2021-12-27  1.132426  1.141151  1.176881
# 2021-12-28  1.133003  1.140584  1.176580
# 2021-12-29  1.131478  1.139949  1.176317
# 2021-12-30  1.136015  1.139360  1.176091
# 2021-12-31  1.132503  1.138759  1.175865
#
# [3127 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3127 entries, 2009-12-31 to 2021-12-31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   3127 non-null   float64
#  1   SMA50   3078 non-null   float64
#  2   SMA200  2928 non-null   float64
# dtypes: float64(3)
# memory usage: 97.7 KB

# %%
fig = go.Figure()

fig.add_traces(go.Scatter(x=data.index, y=data.Close, name='Close'))
fig.add_traces(go.Scatter(x=data.index, y=data.SMA50, name='SMA50'))
fig.add_traces(go.Scatter(x=data.index, y=data.SMA200, name='SMA200'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
fig = go.Figure()

fig.add_traces(go.Scatter(x=data.loc['2018'].index, y=data.loc['2018'].Close, name='Close'))
fig.add_traces(go.Scatter(x=data.loc['2018'].index, y=data.loc['2018'].SMA50, name='SMA50'))
fig.add_traces(go.Scatter(x=data.loc['2018'].index, y=data.loc['2018'].SMA200, name='SMA200'))

fig.update_layout(title='EUR/USD in 2018', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
data['position'] = np.where(data['SMA50'] > data['SMA200'], 1, -1)

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                Close     SMA50    SMA200  position
# time
# 2010-10-06  1.383394  1.304617  1.317550        -1
# 2010-10-07  1.392002  1.306301  1.317347        -1
# 2010-10-08  1.392796  1.308079  1.317116        -1
# 2010-10-11  1.397761  1.309682  1.316892        -1
# 2010-10-12  1.388021  1.310992  1.316650        -1
# ...              ...       ...       ...       ...
# 2021-12-27  1.132426  1.141151  1.176881        -1
# 2021-12-28  1.133003  1.140584  1.176580        -1
# 2021-12-29  1.131478  1.139949  1.176317        -1
# 2021-12-30  1.136015  1.139360  1.176091        -1
# 2021-12-31  1.132503  1.138759  1.175865        -1
#
# [2928 rows x 4 columns]

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x=data.index, y=data.Close, name='Close'))
fig.add_trace(go.Scatter(x=data.index, y=data.SMA50, name='SMA-50'))
fig.add_trace(go.Scatter(x=data.index, y=data.SMA200, name='SMA-200'))
fig.add_trace(go.Scatter(x=data.index, y=data.position, name='Position'), secondary_y=True)

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x=data.loc['2018'].index, y=data.Close, name='Close'))
fig.add_trace(go.Scatter(x=data.loc['2018'].index, y=data.SMA50, name='SMA-50'))
fig.add_trace(go.Scatter(x=data.loc['2018'].index, y=data.SMA200, name='SMA-200'))
fig.add_trace(go.Scatter(x=data.loc['2018'].index, y=data.position, name='Position'), secondary_y=True)

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %% [markdown]
# Defining SMA Strategy

# %%
data
# Out:
#                Close     SMA50    SMA200  position
# time
# 2010-10-06  1.383394  1.304617  1.317550        -1
# 2010-10-07  1.392002  1.306301  1.317347        -1
# 2010-10-08  1.392796  1.308079  1.317116        -1
# 2010-10-11  1.397761  1.309682  1.316892        -1
# 2010-10-12  1.388021  1.310992  1.316650        -1
# ...              ...       ...       ...       ...
# 2021-12-27  1.132426  1.141151  1.176881        -1
# 2021-12-28  1.133003  1.140584  1.176580        -1
# 2021-12-29  1.131478  1.139949  1.176317        -1
# 2021-12-30  1.136015  1.139360  1.176091        -1
# 2021-12-31  1.132503  1.138759  1.175865        -1
#
# [2928 rows x 4 columns]

# %%
data['returns'] = np.log(data.Close.div(data.Close.shift(1)))

# %%
data['strategy'] = data.position.shift(1) * data['returns']

# %%
data
# Out:
#                Close     SMA50    SMA200  position   returns  strategy
# time
# 2010-10-06  1.383394  1.304617  1.317550        -1       NaN       NaN
# 2010-10-07  1.392002  1.306301  1.317347        -1  0.006203 -0.006203
# 2010-10-08  1.392796  1.308079  1.317116        -1  0.000571 -0.000571
# 2010-10-11  1.397761  1.309682  1.316892        -1  0.003558 -0.003558
# 2010-10-12  1.388021  1.310992  1.316650        -1 -0.006992  0.006992
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  1.132426  1.141151  1.176881        -1 -0.000272  0.000272
# 2021-12-28  1.133003  1.140584  1.176580        -1  0.000510 -0.000510
# 2021-12-29  1.131478  1.139949  1.176317        -1 -0.001347  0.001347
# 2021-12-30  1.136015  1.139360  1.176091        -1  0.004002 -0.004002
# 2021-12-31  1.132503  1.138759  1.175865        -1 -0.003097  0.003097
#
# [2928 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %% [markdown]
# RETURNS

# %%
# Absolute Performance
data[['returns', 'strategy']].sum().apply(np.exp)
# Out:
# returns     0.818641
# strategy    1.084900
# dtype: float64

# %%
# Annualized return
data[['returns', 'strategy']].mean() * 252
# Out:
# returns    -0.017228
# strategy    0.007016
# dtype: float64

# %% [markdown]
# RISK

# %%
# Annualized risk
data[['returns', 'strategy']].std() * np.sqrt(252)
# Out:
# returns     0.084484
# strategy    0.084489
# dtype: float64

# %%
data['creturns'] = data['returns'].cumsum().apply(np.exp)
data['cstrategy'] = data['strategy'].cumsum().apply(np.exp)

# %%
data
# Out:
#                Close     SMA50    SMA200  position   returns  strategy  \
# time
# 2010-10-07  1.392002  1.306301  1.317347        -1  0.006203 -0.006203
# 2010-10-08  1.392796  1.308079  1.317116        -1  0.000571 -0.000571
# 2010-10-11  1.397761  1.309682  1.316892        -1  0.003558 -0.003558
# 2010-10-12  1.388021  1.310992  1.316650        -1 -0.006992  0.006992
# 2010-10-13  1.391692  1.312376  1.316406        -1  0.002641 -0.002641
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  1.132426  1.141151  1.176881        -1 -0.000272  0.000272
# 2021-12-28  1.133003  1.140584  1.176580        -1  0.000510 -0.000510
# 2021-12-29  1.131478  1.139949  1.176317        -1 -0.001347  0.001347
# 2021-12-30  1.136015  1.139360  1.176091        -1  0.004002 -0.004002
# 2021-12-31  1.132503  1.138759  1.175865        -1 -0.003097  0.003097
#
#             creturns  cstrategy
# time
# 2010-10-07  1.006222   0.993816
# 2010-10-08  1.006797   0.993249
# 2010-10-11  1.010385   0.989721
# 2010-10-12  1.003345   0.996666
# 2010-10-13  1.005998   0.994038
# ...              ...        ...
# 2021-12-27  0.818585   1.084973
# 2021-12-28  0.819003   1.084420
# 2021-12-29  0.817900   1.085882
# 2021-12-30  0.821180   1.081545
# 2021-12-31  0.818641   1.084900
#
# [2927 rows x 8 columns]

# %%
fig=go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.creturns, name='Returns (Baseline)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy, name='Returns (Strategy)'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
data
# Out:
#                Close     SMA50    SMA200  position   returns  strategy  \
# time
# 2010-10-07  1.392002  1.306301  1.317347        -1  0.006203 -0.006203
# 2010-10-08  1.392796  1.308079  1.317116        -1  0.000571 -0.000571
# 2010-10-11  1.397761  1.309682  1.316892        -1  0.003558 -0.003558
# 2010-10-12  1.388021  1.310992  1.316650        -1 -0.006992  0.006992
# 2010-10-13  1.391692  1.312376  1.316406        -1  0.002641 -0.002641
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  1.132426  1.141151  1.176881        -1 -0.000272  0.000272
# 2021-12-28  1.133003  1.140584  1.176580        -1  0.000510 -0.000510
# 2021-12-29  1.131478  1.139949  1.176317        -1 -0.001347  0.001347
# 2021-12-30  1.136015  1.139360  1.176091        -1  0.004002 -0.004002
# 2021-12-31  1.132503  1.138759  1.175865        -1 -0.003097  0.003097
#
#             creturns  cstrategy
# time
# 2010-10-07  1.006222   0.993816
# 2010-10-08  1.006797   0.993249
# 2010-10-11  1.010385   0.989721
# 2010-10-12  1.003345   0.996666
# 2010-10-13  1.005998   0.994038
# ...              ...        ...
# 2021-12-27  0.818585   1.084973
# 2021-12-28  0.819003   1.084420
# 2021-12-29  0.817900   1.085882
# 2021-12-30  0.821180   1.081545
# 2021-12-31  0.818641   1.084900
#
# [2927 rows x 8 columns]

# %% [markdown]
# Taking trading costs into consideration

# %%
#Per Trade Costs
ptc=0.00007

# %%
data['trades']=data.position.diff().fillna(0).abs()

# %%
data
# Out:
#                Close     SMA50    SMA200  position   returns  strategy  \
# time
# 2010-10-07  1.392002  1.306301  1.317347        -1  0.006203 -0.006203
# 2010-10-08  1.392796  1.308079  1.317116        -1  0.000571 -0.000571
# 2010-10-11  1.397761  1.309682  1.316892        -1  0.003558 -0.003558
# 2010-10-12  1.388021  1.310992  1.316650        -1 -0.006992  0.006992
# 2010-10-13  1.391692  1.312376  1.316406        -1  0.002641 -0.002641
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  1.132426  1.141151  1.176881        -1 -0.000272  0.000272
# 2021-12-28  1.133003  1.140584  1.176580        -1  0.000510 -0.000510
# 2021-12-29  1.131478  1.139949  1.176317        -1 -0.001347  0.001347
# 2021-12-30  1.136015  1.139360  1.176091        -1  0.004002 -0.004002
# 2021-12-31  1.132503  1.138759  1.175865        -1 -0.003097  0.003097
#
#             creturns  cstrategy  trades
# time
# 2010-10-07  1.006222   0.993816     0.0
# 2010-10-08  1.006797   0.993249     0.0
# 2010-10-11  1.010385   0.989721     0.0
# 2010-10-12  1.003345   0.996666     0.0
# 2010-10-13  1.005998   0.994038     0.0
# ...              ...        ...     ...
# 2021-12-27  0.818585   1.084973     0.0
# 2021-12-28  0.819003   1.084420     0.0
# 2021-12-29  0.817900   1.085882     0.0
# 2021-12-30  0.821180   1.081545     0.0
# 2021-12-31  0.818641   1.084900     0.0
#
# [2927 rows x 9 columns]

# %%
data.trades.value_counts()
# Out:
# 0.0    2909
# 2.0      18
# Name: trades, dtype: int64

# %%
data['strategy_net']=data.strategy-data.trades*ptc

# %%
data['cstrategy_net']=data.strategy_net.cumsum().apply(np.exp)

# %%
data
# Out:
#                Close     SMA50    SMA200  position   returns  strategy  \
# time
# 2010-10-07  1.392002  1.306301  1.317347        -1  0.006203 -0.006203
# 2010-10-08  1.392796  1.308079  1.317116        -1  0.000571 -0.000571
# 2010-10-11  1.397761  1.309682  1.316892        -1  0.003558 -0.003558
# 2010-10-12  1.388021  1.310992  1.316650        -1 -0.006992  0.006992
# 2010-10-13  1.391692  1.312376  1.316406        -1  0.002641 -0.002641
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  1.132426  1.141151  1.176881        -1 -0.000272  0.000272
# 2021-12-28  1.133003  1.140584  1.176580        -1  0.000510 -0.000510
# 2021-12-29  1.131478  1.139949  1.176317        -1 -0.001347  0.001347
# 2021-12-30  1.136015  1.139360  1.176091        -1  0.004002 -0.004002
# 2021-12-31  1.132503  1.138759  1.175865        -1 -0.003097  0.003097
#
#             creturns  cstrategy  trades  strategy_net  cstrategy_net
# time
# 2010-10-07  1.006222   0.993816     0.0     -0.006203       0.993816
# 2010-10-08  1.006797   0.993249     0.0     -0.000571       0.993249
# 2010-10-11  1.010385   0.989721     0.0     -0.003558       0.989721
# 2010-10-12  1.003345   0.996666     0.0      0.006992       0.996666
# 2010-10-13  1.005998   0.994038     0.0     -0.002641       0.994038
# ...              ...        ...     ...           ...            ...
# 2021-12-27  0.818585   1.084973     0.0      0.000272       1.082242
# 2021-12-28  0.819003   1.084420     0.0     -0.000510       1.081691
# 2021-12-29  0.817900   1.085882     0.0      0.001347       1.083149
# 2021-12-30  0.821180   1.081545     0.0     -0.004002       1.078823
# 2021-12-31  0.818641   1.084900     0.0      0.003097       1.082169
#
# [2927 rows x 11 columns]

# %% [markdown]
# Plot returns with and without trading costs

# %%
fig=go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.creturns, name='Returns (Baseline)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy, name='Returns (Strategy)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy_net, name='Returns (Strategy + trading costs)'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
data[['returns', 'strategy_net']].mean() * (252)
data[['returns', 'strategy_net']].std() * np.sqrt(252)
# Out:
# returns         0.084484
# strategy_net    0.084489
# dtype: float64

# %% [markdown]
# Now we make use of a comprehensive backtester which implements SMA and optimize our parameters to maximize returns

# %%
from SMABacktester import SMABacktester as SMA

# %%
testSMA = SMA(symbol='EUR/USD', SMA_S=30, SMA_L=50,  start='2010', end='2021', tc=0.00007)

# %%
testSMA
# Out:
# SMABacktester(symbol = EUR/USD, SMA_S = 30,  SMA_L = 50, start = 2010, end = 2021, tc=7e-05)

# %%
testSMA.data
# Out:
#                Close   returns     SMA_S     SMA_L
# time
# 2010-01-01  1.438994       NaN       NaN       NaN
# 2010-01-04  1.442398  0.002363       NaN       NaN
# 2010-01-05  1.436596 -0.004031       NaN       NaN
# 2010-01-06  1.440403  0.002647       NaN       NaN
# 2010-01-07  1.431803 -0.005989       NaN       NaN
# ...              ...       ...       ...       ...
# 2021-12-27  1.132426 -0.000272  1.129582  1.141151
# 2021-12-28  1.133003  0.000510  1.129461  1.140584
# 2021-12-29  1.131478 -0.001347  1.129439  1.139949
# 2021-12-30  1.136015  0.004002  1.129569  1.139360
# 2021-12-31  1.132503 -0.003097  1.129425  1.138759
#
# [3126 rows x 4 columns]

# %%
testSMA.test_strategy()
# Out:
# (1.18598, 0.358449)

# %%
testSMA.results
# Out:
#                Close   returns     SMA_S     SMA_L  position  strategy  \
# time
# 2010-03-12  1.376993  0.006164  1.366841  1.391025        -1 -0.006164
# 2010-03-15  1.367746 -0.006738  1.366009  1.389532        -1  0.006738
# 2010-03-16  1.376879  0.006656  1.365318  1.388338        -1 -0.006656
# 2010-03-17  1.373834 -0.002214  1.364775  1.387006        -1  0.002214
# 2010-03-18  1.361396 -0.009094  1.364339  1.385598        -1  0.009094
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  1.132426 -0.000272  1.129582  1.141151        -1  0.000272
# 2021-12-28  1.133003  0.000510  1.129461  1.140584        -1 -0.000510
# 2021-12-29  1.131478 -0.001347  1.129439  1.139949        -1  0.001347
# 2021-12-30  1.136015  0.004002  1.129569  1.139360        -1 -0.004002
# 2021-12-31  1.132503 -0.003097  1.129425  1.138759        -1  0.003097
#
#             trades  strategy_net  creturns  cstrategy  cstrategy_net
# time
# 2010-03-12     0.0     -0.006164  1.006183   0.993855       0.993855
# 2010-03-15     0.0      0.006738  0.999426   1.000575       1.000575
# 2010-03-16     0.0     -0.006656  1.006100   0.993937       0.993937
# 2010-03-17     0.0      0.002214  1.003874   0.996141       0.996141
# 2010-03-18     0.0      0.009094  0.994786   1.005241       1.005241
# ...            ...           ...       ...        ...            ...
# 2021-12-27     0.0      0.000272  0.827475   1.186061       1.175152
# 2021-12-28     0.0     -0.000510  0.827897   1.185457       1.174553
# 2021-12-29     0.0      0.001347  0.826782   1.187055       1.176137
# 2021-12-30     0.0     -0.004002  0.830098   1.182314       1.171439
# 2021-12-31     0.0      0.003097  0.827531   1.185980       1.175073
#
# [3076 rows x 11 columns]

# %%
testSMA.results.trades.value_counts()
# Out:
# 0.0    3010
# 2.0      66
# Name: trades, dtype: int64

# %%
testSMA.plot_results()

# %% [markdown]
# We give a set of boundaries to optimize our parameters within
#
# SMA_S describes the lower range of days for which simple moving average must be taken
#
# SMA_L describes the upper range of days for which simple moving average must be taken

# %%
SMA_S = (10, 50, 1)
SMA_L =  (100, 252, 1)

# %%
testSMA.optimize_parameters(SMA_S_range=SMA_S, SMA_L_range=SMA_L)
# Out:
# ((49, 239), 1.726985)

# %%
testSMA.test_strategy()
# Out:
# (1.726985, 0.855297)

# %% [markdown]
# Set of parameters which give maximum returns and a plot of returns for the same

# %%
testSMA.plot_results()

# %%
#Return
testSMA.results[['returns', 'strategy_net']].mean() * (252)
# Out:
# returns        -0.011987
# strategy_net    0.047582
# dtype: float64

# %%
#Risk
testSMA.results[['returns', 'strategy_net']].std() * np.sqrt(252)
# Out:
# returns         0.083742
# strategy_net    0.083689
# dtype: float64
