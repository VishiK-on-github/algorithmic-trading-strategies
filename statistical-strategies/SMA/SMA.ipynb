# %% [markdown]
# ## Simple Moving Average

# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
data = pd.read_csv(filepath_or_buffer='../../resources/S&P500.csv', parse_dates=['Date'], index_col='Date')

# %%
data.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2009-12-31  1126.599976  1127.640015  1114.810059  1115.099976  1115.099976
# 2010-01-04  1116.560059  1133.869995  1116.560059  1132.989990  1132.989990
# 2010-01-05  1132.660034  1136.630005  1129.660034  1136.520020  1136.520020
# 2010-01-06  1135.709961  1139.189941  1133.949951  1137.140015  1137.140015
# 2010-01-07  1136.270020  1142.459961  1131.319946  1141.689941  1141.689941
#
#                 Volume
# Date
# 2009-12-31  2076990000
# 2010-01-04  3991400000
# 2010-01-05  2491020000
# 2010-01-06  4972660000
# 2010-01-07  5270680000

# %%
data.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-02-28  4354.169922  4388.839844  4315.120117  4373.939941  4373.939941
# 2022-03-01  4363.140137  4378.450195  4279.540039  4306.259766  4306.259766
# 2022-03-02  4322.560059  4401.479980  4322.560059  4386.540039  4386.540039
# 2022-03-03  4401.310059  4416.779785  4345.560059  4363.490234  4363.490234
# 2022-03-04  4342.120117  4342.120117  4284.979980  4328.870117  4328.870117
#
#                 Volume
# Date
# 2022-02-28  4594010000
# 2022-03-01  4679400000
# 2022-03-02  4409090000
# 2022-03-03  4062080000
# 2022-03-04  2997073000

# %%
data.Close.to_frame()
# Out:
#                   Close
# Date
# 2009-12-31  1115.099976
# 2010-01-04  1132.989990
# 2010-01-05  1136.520020
# 2010-01-06  1137.140015
# 2010-01-07  1141.689941
# ...                 ...
# 2022-02-28  4373.939941
# 2022-03-01  4306.259766
# 2022-03-02  4386.540039
# 2022-03-03  4363.490234
# 2022-03-04  4328.870117
#
# [3065 rows x 1 columns]

# %%
data = data.Close.to_frame()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.Close, name='Close'))

fig.update_layout(title='S&P500', xaxis_title='Years', yaxis_title='Closing Price')

fig.show()

# %%
data['SMA50'] = data.rolling(window=50, min_periods=50).mean()

# %%
data['SMA200'] = data.Close.rolling(window=200, min_periods=200).mean()

# %%
data
# Out:
#                   Close        SMA50       SMA200
# Date
# 2009-12-31  1115.099976          NaN          NaN
# 2010-01-04  1132.989990          NaN          NaN
# 2010-01-05  1136.520020          NaN          NaN
# 2010-01-06  1137.140015          NaN          NaN
# 2010-01-07  1141.689941          NaN          NaN
# ...                 ...          ...          ...
# 2022-02-28  4373.939941  4552.087178  4462.025483
# 2022-03-01  4306.259766  4544.838975  4462.687532
# 2022-03-02  4386.540039  4540.156973  4463.803782
# 2022-03-03  4363.490234  4536.066377  4464.982083
# 2022-03-04  4328.870117  4529.659180  4466.048032
#
# [3065 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3065 entries, 2009-12-31 to 2022-03-04
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   3065 non-null   float64
#  1   SMA50   3016 non-null   float64
#  2   SMA200  2866 non-null   float64
# dtypes: float64(3)
# memory usage: 95.8 KB

# %%
fig = go.Figure()

fig.add_traces(go.Scatter(x=data.index, y=data.Close, name='Close'))
fig.add_traces(go.Scatter(x=data.index, y=data.SMA50, name='SMA50'))
fig.add_traces(go.Scatter(x=data.index, y=data.SMA200, name='SMA200'))

fig.update_layout(title='S&P500', xaxis_title='Years', yaxis_title='Closing Price')

fig.show()

# %%
fig = go.Figure()

fig.add_traces(go.Scatter(x=data.index, y=data.SMA50, name='SMA50'))
fig.add_traces(go.Scatter(x=data.index, y=data.SMA200, name='SMA200'))

fig.update_layout(title='S&P500', xaxis_title='Years', yaxis_title='Closing Price')

fig.show()

# %%
fig = go.Figure()

fig.add_traces(go.Scatter(x=data.loc['2016'].index, y=data.loc['2016'].Close, name='Close'))
fig.add_traces(go.Scatter(x=data.loc['2016'].index, y=data.loc['2016'].SMA50, name='SMA50'))
fig.add_traces(go.Scatter(x=data.loc['2016'].index, y=data.loc['2016'].SMA200, name='SMA200'))

fig.update_layout(title='S&P500 in 2016', xaxis_title='Year', yaxis_title='Closing Price')

fig.show()
