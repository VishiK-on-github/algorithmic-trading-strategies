# %% [markdown]
# ## Momentum Strategy

# %% [markdown]
# Importing dependencies

# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# %% [markdown]
# Fetching the data source and converting to pandas dataframe

# %%
data = pd.read_csv(filepath_or_buffer='../../resources/intraday.csv', parse_dates=['time'], index_col='time')

# %% [markdown]
# Getting details about the asset data by analysing the dataframe

# %%
data.head(10)
# Out:
#                               Close
# time
# 2018-01-01 22:00:00+00:00  1.201205
# 2018-01-02 04:00:00+00:00  1.207055
# 2018-01-02 10:00:00+00:00  1.204440
# 2018-01-02 16:00:00+00:00  1.205800
# 2018-01-02 22:00:00+00:00  1.204690
# 2018-01-03 04:00:00+00:00  1.203825
# 2018-01-03 10:00:00+00:00  1.202355
# 2018-01-03 16:00:00+00:00  1.201445
# 2018-01-03 22:00:00+00:00  1.201450
# 2018-01-04 04:00:00+00:00  1.204300

# %%
data.tail(10)
# Out:
#                               Close
# time
# 2019-12-26 16:00:00+00:00  1.109655
# 2019-12-26 22:00:00+00:00  1.111890
# 2019-12-27 04:00:00+00:00  1.113860
# 2019-12-27 10:00:00+00:00  1.116300
# 2019-12-27 16:00:00+00:00  1.117580
# 2019-12-29 22:00:00+00:00  1.119920
# 2019-12-30 04:00:00+00:00  1.119940
# 2019-12-30 10:00:00+00:00  1.120095
# 2019-12-30 16:00:00+00:00  1.119920
# 2019-12-30 22:00:00+00:00  1.120355

# %%
data.Close.to_frame()
# Out:
#                               Close
# time
# 2018-01-01 22:00:00+00:00  1.201205
# 2018-01-02 04:00:00+00:00  1.207055
# 2018-01-02 10:00:00+00:00  1.204440
# 2018-01-02 16:00:00+00:00  1.205800
# 2018-01-02 22:00:00+00:00  1.204690
# ...                             ...
# 2019-12-29 22:00:00+00:00  1.119920
# 2019-12-30 04:00:00+00:00  1.119940
# 2019-12-30 10:00:00+00:00  1.120095
# 2019-12-30 16:00:00+00:00  1.119920
# 2019-12-30 22:00:00+00:00  1.120355
#
# [2070 rows x 1 columns]

# %% [markdown]
# Getting more statistical insight into the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2070 entries, 2018-01-01 22:00:00+00:00 to 2019-12-30 22:00:00+00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2070 non-null   float64
# dtypes: float64(1)
# memory usage: 32.3 KB

# %%
data.describe()
# Out:
#              Close
# count  2070.000000
# mean      1.150400
# std       0.041544
# min       1.088635
# 25%       1.119714
# 50%       1.137698
# 75%       1.169170
# max       1.253920

# %% [markdown]
# Since the only attribute we need is closing price
# we modify the data frame

# %%
data = data.Close.to_frame()

# %%
data.head(10)
# Out:
#                               Close
# time
# 2018-01-01 22:00:00+00:00  1.201205
# 2018-01-02 04:00:00+00:00  1.207055
# 2018-01-02 10:00:00+00:00  1.204440
# 2018-01-02 16:00:00+00:00  1.205800
# 2018-01-02 22:00:00+00:00  1.204690
# 2018-01-03 04:00:00+00:00  1.203825
# 2018-01-03 10:00:00+00:00  1.202355
# 2018-01-03 16:00:00+00:00  1.201445
# 2018-01-03 22:00:00+00:00  1.201450
# 2018-01-04 04:00:00+00:00  1.204300

# %% [markdown]
# We plot the closing price of our asset

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.Close, name='Close'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.loc['2018'].index, y=data.loc['2018'].Close, name='Close'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %% [markdown]
# We proceed to define baseline and compute returns !needs improvement!

# %%
data['returns'] = np.log(data.div(data.shift(1)))

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                               Close   returns
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169
# 2018-01-02 16:00:00+00:00  1.205800  0.001129
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718
# ...                             ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388
#
# [2069 rows x 2 columns]

# %% [markdown]
# Defining a simple contrarian strategy (window = 3)

# %%
window = 3

# %%
data['returns'].rolling(window).mean()
# Out:
# time
# 2018-01-02 04:00:00+00:00             NaN
# 2018-01-02 10:00:00+00:00             NaN
# 2018-01-02 16:00:00+00:00    1.272676e-03
# 2018-01-02 22:00:00+00:00   -6.537454e-04
# 2018-01-03 04:00:00+00:00   -1.702470e-04
#                                  ...
# 2019-12-29 22:00:00+00:00    1.808598e-03
# 2019-12-30 04:00:00+00:00    1.085156e-03
# 2019-12-30 10:00:00+00:00    7.492899e-04
# 2019-12-30 16:00:00+00:00   -1.484453e-17
# 2019-12-30 22:00:00+00:00    1.234956e-04
# Name: returns, Length: 2069, dtype: float64

# %%
data['position'] = np.sign(data['returns'].rolling(window).mean())

# %%
data
# Out:
#                               Close   returns  position
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858       NaN
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169       NaN
# 2018-01-02 16:00:00+00:00  1.205800  0.001129       1.0
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921      -1.0
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718      -1.0
# ...                             ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092       1.0
# 2019-12-30 04:00:00+00:00  1.119940  0.000018       1.0
# 2019-12-30 10:00:00+00:00  1.120095  0.000138       1.0
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156      -1.0
# 2019-12-30 22:00:00+00:00  1.120355  0.000388       1.0
#
# [2069 rows x 3 columns]

# %%
data['strategy'] = data.position.shift(1) * data['returns']

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                               Close   returns  position  strategy
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921      -1.0 -0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718      -1.0  0.000718
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222      -1.0  0.001222
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757      -1.0  0.000757
# 2018-01-03 22:00:00+00:00  1.201450  0.000004      -1.0 -0.000004
# ...                             ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092       1.0  0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018       1.0  0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138       1.0  0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156      -1.0 -0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388       1.0 -0.000388
#
# [2066 rows x 4 columns]

# %%
data[['returns', 'strategy']].sum()
# Out:
# returns    -0.073498
# strategy   -0.096236
# dtype: float64

# %%
data['creturns'] = data['returns'].cumsum().apply(np.exp)
data['cstrategy'] = data['strategy'].cumsum().apply(np.exp)

# %%
data
# Out:
#                               Close   returns  position  strategy  creturns  \
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921      -1.0 -0.000921  0.999079
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718      -1.0  0.000718  0.998362
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222      -1.0  0.001222  0.997143
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757      -1.0  0.000757  0.996388
# 2018-01-03 22:00:00+00:00  1.201450  0.000004      -1.0 -0.000004  0.996392
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092       1.0  0.002092  0.928778
# 2019-12-30 04:00:00+00:00  1.119940  0.000018       1.0  0.000018  0.928794
# 2019-12-30 10:00:00+00:00  1.120095  0.000138       1.0  0.000138  0.928923
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156      -1.0 -0.000156  0.928778
# 2019-12-30 22:00:00+00:00  1.120355  0.000388       1.0 -0.000388  0.929138
#
#                            cstrategy
# time
# 2018-01-02 22:00:00+00:00   0.999079
# 2018-01-03 04:00:00+00:00   0.999797
# 2018-01-03 10:00:00+00:00   1.001020
# 2018-01-03 16:00:00+00:00   1.001778
# 2018-01-03 22:00:00+00:00   1.001774
# ...                              ...
# 2019-12-29 22:00:00+00:00   0.908602
# 2019-12-30 04:00:00+00:00   0.908619
# 2019-12-30 10:00:00+00:00   0.908744
# 2019-12-30 16:00:00+00:00   0.908602
# 2019-12-30 22:00:00+00:00   0.908250
#
# [2066 rows x 6 columns]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.creturns, name='Returns (Baseline)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy, name='Returns (Strategy)'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %% [markdown]
# Taking trading costs into consideration

# %%
ptc = 0.00007

# %%
data['trades'] = data.position.diff().fillna(0).abs()

# %%
data
# Out:
#                               Close   returns  position  strategy  creturns  \
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921      -1.0 -0.000921  0.999079
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718      -1.0  0.000718  0.998362
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222      -1.0  0.001222  0.997143
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757      -1.0  0.000757  0.996388
# 2018-01-03 22:00:00+00:00  1.201450  0.000004      -1.0 -0.000004  0.996392
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092       1.0  0.002092  0.928778
# 2019-12-30 04:00:00+00:00  1.119940  0.000018       1.0  0.000018  0.928794
# 2019-12-30 10:00:00+00:00  1.120095  0.000138       1.0  0.000138  0.928923
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156      -1.0 -0.000156  0.928778
# 2019-12-30 22:00:00+00:00  1.120355  0.000388       1.0 -0.000388  0.929138
#
#                            cstrategy  trades
# time
# 2018-01-02 22:00:00+00:00   0.999079     0.0
# 2018-01-03 04:00:00+00:00   0.999797     0.0
# 2018-01-03 10:00:00+00:00   1.001020     0.0
# 2018-01-03 16:00:00+00:00   1.001778     0.0
# 2018-01-03 22:00:00+00:00   1.001774     0.0
# ...                              ...     ...
# 2019-12-29 22:00:00+00:00   0.908602     0.0
# 2019-12-30 04:00:00+00:00   0.908619     0.0
# 2019-12-30 10:00:00+00:00   0.908744     0.0
# 2019-12-30 16:00:00+00:00   0.908602     2.0
# 2019-12-30 22:00:00+00:00   0.908250     2.0
#
# [2066 rows x 7 columns]

# %%
data.trades.value_counts()
# Out:
# 0.0    1513
# 2.0     553
# Name: trades, dtype: int64

# %%
data['strategy_net'] = data.strategy - data.trades * ptc

# %%
data['cstrategy_net'] = data.strategy_net.cumsum().apply(np.exp)

# %%
data
# Out:
#                               Close   returns  position  strategy  creturns  \
# time
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921      -1.0 -0.000921  0.999079
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718      -1.0  0.000718  0.998362
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222      -1.0  0.001222  0.997143
# 2018-01-03 16:00:00+00:00  1.201445 -0.000757      -1.0  0.000757  0.996388
# 2018-01-03 22:00:00+00:00  1.201450  0.000004      -1.0 -0.000004  0.996392
# ...                             ...       ...       ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092       1.0  0.002092  0.928778
# 2019-12-30 04:00:00+00:00  1.119940  0.000018       1.0  0.000018  0.928794
# 2019-12-30 10:00:00+00:00  1.120095  0.000138       1.0  0.000138  0.928923
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156      -1.0 -0.000156  0.928778
# 2019-12-30 22:00:00+00:00  1.120355  0.000388       1.0 -0.000388  0.929138
#
#                            cstrategy  trades  strategy_net  cstrategy_net
# time
# 2018-01-02 22:00:00+00:00   0.999079     0.0     -0.000921       0.999079
# 2018-01-03 04:00:00+00:00   0.999797     0.0      0.000718       0.999797
# 2018-01-03 10:00:00+00:00   1.001020     0.0      0.001222       1.001020
# 2018-01-03 16:00:00+00:00   1.001778     0.0      0.000757       1.001778
# 2018-01-03 22:00:00+00:00   1.001774     0.0     -0.000004       1.001774
# ...                              ...     ...           ...            ...
# 2019-12-29 22:00:00+00:00   0.908602     0.0      0.002092       0.841148
# 2019-12-30 04:00:00+00:00   0.908619     0.0      0.000018       0.841163
# 2019-12-30 10:00:00+00:00   0.908744     0.0      0.000138       0.841279
# 2019-12-30 16:00:00+00:00   0.908602     2.0     -0.000296       0.841030
# 2019-12-30 22:00:00+00:00   0.908250     2.0     -0.000528       0.840586
#
# [2066 rows x 9 columns]

# %% [markdown]
# We plot returns with and without trading costs

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.creturns, name='Returns (Baseline)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy, name='Returns (Strategy)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy_net, name='Returns (Strategy + trading costs)'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
data[['returns', 'strategy_net']].mean() * (4*252)
# Out:
# returns        -0.035859
# strategy_net   -0.084727
# dtype: float64

# %%
data[['returns', 'strategy_net']].std() * np.sqrt(4*252)
# Out:
# returns         0.059878
# strategy_net    0.060892
# dtype: float64

# %% [markdown]
# Now we make use of a comprehensive backtester which implements Contrarian startegy and optimize our parameters to maximize returns

# %%
from MomentumContrarianBacktester import MomentumContrarianBacktester as MCB

# %%
testMCB = MCB(symbol='EUR/USD', start='2018', end='2020', tc=0.00007, flag='m')

# %%
testMCB
# Out:
# MomentumContrarianBacktester(symbol = EUR/USD, start = 2018, end = 2020, flag = m)

# %%
testMCB.data
# Out:
#                               Close   returns
# time
# 2018-01-02 04:00:00+00:00  1.207055  0.004858
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169
# 2018-01-02 16:00:00+00:00  1.205800  0.001129
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718
# ...                             ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092
# 2019-12-30 04:00:00+00:00  1.119940  0.000018
# 2019-12-30 10:00:00+00:00  1.120095  0.000138
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156
# 2019-12-30 22:00:00+00:00  1.120355  0.000388
#
# [2069 rows x 2 columns]

# %%
testMCB.test_strategy()
# Out:
# (0.897488, -0.030684)

# %%
testMCB.results
# Out:
#                               Close   returns  position  strategy  trades  \
# time
# 2018-01-02 10:00:00+00:00  1.204440 -0.002169      -1.0 -0.002169     0.0
# 2018-01-02 16:00:00+00:00  1.205800  0.001129       1.0 -0.001129     2.0
# 2018-01-02 22:00:00+00:00  1.204690 -0.000921      -1.0 -0.000921     2.0
# 2018-01-03 04:00:00+00:00  1.203825 -0.000718      -1.0  0.000718     0.0
# 2018-01-03 10:00:00+00:00  1.202355 -0.001222      -1.0  0.001222     0.0
# ...                             ...       ...       ...       ...     ...
# 2019-12-29 22:00:00+00:00  1.119920  0.002092       1.0  0.002092     0.0
# 2019-12-30 04:00:00+00:00  1.119940  0.000018       1.0  0.000018     0.0
# 2019-12-30 10:00:00+00:00  1.120095  0.000138       1.0  0.000138     0.0
# 2019-12-30 16:00:00+00:00  1.119920 -0.000156      -1.0 -0.000156     2.0
# 2019-12-30 22:00:00+00:00  1.120355  0.000388       1.0 -0.000388     2.0
#
#                            strategy_net  creturns  cstrategy  cstrategy_net
# time
# 2018-01-02 10:00:00+00:00     -0.002169  0.997834   0.997834       0.997834
# 2018-01-02 16:00:00+00:00     -0.001269  0.998960   0.996708       0.996569
# 2018-01-02 22:00:00+00:00     -0.001061  0.998041   0.995791       0.995512
# 2018-01-03 04:00:00+00:00      0.000718  0.997324   0.996506       0.996227
# 2018-01-03 10:00:00+00:00      0.001222  0.996106   0.997724       0.997445
# ...                                 ...       ...        ...            ...
# 2019-12-29 22:00:00+00:00      0.002092  0.927812   0.897837       0.776618
# 2019-12-30 04:00:00+00:00      0.000018  0.927828   0.897853       0.776632
# 2019-12-30 10:00:00+00:00      0.000138  0.927957   0.897977       0.776739
# 2019-12-30 16:00:00+00:00     -0.000296  0.927812   0.897837       0.776509
# 2019-12-30 22:00:00+00:00     -0.000528  0.928172   0.897488       0.776099
#
# [2068 rows x 9 columns]

# %% [markdown]
# We find the number of trades made

# %%
testMCB.results.trades.value_counts()
# Out:
# 2.0    1033
# 0.0    1025
# 1.0      10
# Name: trades, dtype: int64

# %%
testMCB.plot_results()

# %% [markdown]
# We give a set of boundaries to optimize our parameters within
#
# window_range describes the range of days over which need to be taken into consideration

# %%
window_range = (1, 200)

# %%
testMCB.optimize_parameter(window_range=window_range)
# Out:
# (4, 1.141609)

# %%
testMCB.test_strategy(window=4)
# Out:
# (1.141609, 0.211615)

# %% [markdown]
# Set of parameters which give maximum returns and a plot of returns for the same

# %%
testMCB.plot_results()
