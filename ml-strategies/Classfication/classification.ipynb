# %% [markdown]
# ## Classification

# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv(filepath_or_buffer='../../resources/train_set.csv', parse_dates=['time'], index_col='time')

# %%
data.head(10)
# Out:
#                Close
# time
# 2009-12-31  1.432706
# 2010-01-01  1.438994
# 2010-01-04  1.442398
# 2010-01-05  1.436596
# 2010-01-06  1.440403
# 2010-01-07  1.431803
# 2010-01-08  1.441109
# 2010-01-11  1.451126
# 2010-01-12  1.447660
# 2010-01-13  1.452391

# %%
data.tail(10)
# Out:
#                Close
# time
# 2020-12-18  1.226272
# 2020-12-21  1.221613
# 2020-12-22  1.223691
# 2020-12-23  1.218665
# 2020-12-24  1.219141
# 2020-12-25  1.218472
# 2020-12-28  1.220510
# 2020-12-29  1.222345
# 2020-12-30  1.225295
# 2020-12-31  1.229990

# %%
data.Close.to_frame()
# Out:
#                Close
# time
# 2009-12-31  1.432706
# 2010-01-01  1.438994
# 2010-01-04  1.442398
# 2010-01-05  1.436596
# 2010-01-06  1.440403
# ...              ...
# 2020-12-25  1.218472
# 2020-12-28  1.220510
# 2020-12-29  1.222345
# 2020-12-30  1.225295
# 2020-12-31  1.229990
#
# [2866 rows x 1 columns]

# %% [markdown]
# Getting more statistical insight into the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2866 entries, 2009-12-31 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2866 non-null   float64
# dtypes: float64(1)
# memory usage: 44.8 KB

# %%
data.describe()
# Out:
#              Close
# count  2866.000000
# mean      1.222946
# std       0.111835
# min       1.039047
# 25%       1.121604
# 50%       1.193859
# 75%       1.323745
# max       1.484406

# %% [markdown]
# Since the only attribute we need is closing price
# we modify the data frame

# %%
data = data.Close.to_frame()

# %%
data.head(10)
# Out:
#                Close
# time
# 2009-12-31  1.432706
# 2010-01-01  1.438994
# 2010-01-04  1.442398
# 2010-01-05  1.436596
# 2010-01-06  1.440403
# 2010-01-07  1.431803
# 2010-01-08  1.441109
# 2010-01-11  1.451126
# 2010-01-12  1.447660
# 2010-01-13  1.452391

# %% [markdown]
# Since the only attribute we need is closing price
# we modify the data frame

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.Close, name='Close'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
data['returns'] = np.log(data.div(data.shift(1)))

# %%
data.dropna(inplace=True)

# %%
data['direction'] = np.sign(data.returns)

# %%
data
# Out:
#                Close   returns  direction
# time
# 2010-01-01  1.438994  0.004379        1.0
# 2010-01-04  1.442398  0.002363        1.0
# 2010-01-05  1.436596 -0.004031       -1.0
# 2010-01-06  1.440403  0.002647        1.0
# 2010-01-07  1.431803 -0.005989       -1.0
# ...              ...       ...        ...
# 2020-12-25  1.218472 -0.000549       -1.0
# 2020-12-28  1.220510  0.001671        1.0
# 2020-12-29  1.222345  0.001502        1.0
# 2020-12-30  1.225295  0.002411        1.0
# 2020-12-31  1.229990  0.003824        1.0
#
# [2865 rows x 3 columns]

# %%
data.direction.value_counts()
# Out:
#  1.0    1434
# -1.0    1414
#  0.0      17
# Name: direction, dtype: int64

# %%
lags = 5

# %%
cols = []
for lag in range(1, lags+1):

  col = f'lag{lag}'
  data[col] = data.returns.shift(lag)
  cols.append(col)

data.dropna(inplace=True)

# %%
data
# Out:
#                Close   returns  direction      lag1      lag2      lag3  \
# time
# 2010-01-08  1.441109  0.006478        1.0 -0.005989  0.002647 -0.004031
# 2010-01-11  1.451126  0.006927        1.0  0.006478 -0.005989  0.002647
# 2010-01-12  1.447660 -0.002391       -1.0  0.006927  0.006478 -0.005989
# 2010-01-13  1.452391  0.003262        1.0 -0.002391  0.006927  0.006478
# 2010-01-14  1.449990 -0.001654       -1.0  0.003262 -0.002391  0.006927
# ...              ...       ...        ...       ...       ...       ...
# 2020-12-25  1.218472 -0.000549       -1.0  0.000390 -0.004115  0.001699
# 2020-12-28  1.220510  0.001671        1.0 -0.000549  0.000390 -0.004115
# 2020-12-29  1.222345  0.001502        1.0  0.001671 -0.000549  0.000390
# 2020-12-30  1.225295  0.002411        1.0  0.001502  0.001671 -0.000549
# 2020-12-31  1.229990  0.003824        1.0  0.002411  0.001502  0.001671
#
#                 lag4      lag5
# time
# 2010-01-08  0.002363  0.004379
# 2010-01-11 -0.004031  0.002363
# 2010-01-12  0.002647 -0.004031
# 2010-01-13 -0.005989  0.002647
# 2010-01-14  0.006478 -0.005989
# ...              ...       ...
# 2020-12-25 -0.003806  0.005161
# 2020-12-28  0.001699 -0.003806
# 2020-12-29 -0.004115  0.001699
# 2020-12-30  0.000390 -0.004115
# 2020-12-31 -0.000549  0.000390
#
# [2860 rows x 8 columns]

# %%
LR = LogisticRegression(C=1e6, max_iter=100000, multi_class='ovr')

# %%
LR.fit(data[cols], data.direction)
# Out:
# LogisticRegression(C=1000000.0, max_iter=100000, multi_class='ovr')

# %%
data['predict_diff'] = LR.predict(X=data[cols])

# %%
data
# Out:
#                Close   returns  direction      lag1      lag2      lag3  \
# time
# 2010-01-08  1.441109  0.006478        1.0 -0.005989  0.002647 -0.004031
# 2010-01-11  1.451126  0.006927        1.0  0.006478 -0.005989  0.002647
# 2010-01-12  1.447660 -0.002391       -1.0  0.006927  0.006478 -0.005989
# 2010-01-13  1.452391  0.003262        1.0 -0.002391  0.006927  0.006478
# 2010-01-14  1.449990 -0.001654       -1.0  0.003262 -0.002391  0.006927
# ...              ...       ...        ...       ...       ...       ...
# 2020-12-25  1.218472 -0.000549       -1.0  0.000390 -0.004115  0.001699
# 2020-12-28  1.220510  0.001671        1.0 -0.000549  0.000390 -0.004115
# 2020-12-29  1.222345  0.001502        1.0  0.001671 -0.000549  0.000390
# 2020-12-30  1.225295  0.002411        1.0  0.001502  0.001671 -0.000549
# 2020-12-31  1.229990  0.003824        1.0  0.002411  0.001502  0.001671
#
#                 lag4      lag5  predict_diff
# time
# 2010-01-08  0.002363  0.004379           1.0
# 2010-01-11 -0.004031  0.002363          -1.0
# 2010-01-12  0.002647 -0.004031          -1.0
# 2010-01-13 -0.005989  0.002647           1.0
# 2010-01-14  0.006478 -0.005989          -1.0
# ...              ...       ...           ...
# 2020-12-25 -0.003806  0.005161           1.0
# 2020-12-28  0.001699 -0.003806           1.0
# 2020-12-29 -0.004115  0.001699           1.0
# 2020-12-30  0.000390 -0.004115          -1.0
# 2020-12-31 -0.000549  0.000390          -1.0
#
# [2860 rows x 9 columns]

# %%
data.predict_diff.value_counts()
# Out:
#  1.0    1590
# -1.0    1270
# Name: predict_diff, dtype: int64

# %%
hits = np.sign(data.direction * data.predict_diff).value_counts()
hits
# Out:
#  1.0    1478
# -1.0    1365
#  0.0      17
# dtype: int64

# %%
hit_ratio = hits[1.0] / sum(hits)
hit_ratio
# Out:
# 0.5167832167832168

# %% [markdown]
# In sample backtesting and look ahead bias

# %%
data['strategy'] = data.predict_diff * data.returns

# %%
data['creturns'] = data['returns'].cumsum().apply(np.exp)
data['cstrategy'] = data['strategy'].cumsum().apply(np.exp)

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.creturns, name='Returns (Baseline)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy, name='Returns (Strategy)'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
data['trades'] = data.predict_diff.diff().fillna(0).abs()

# %%
data.trades.value_counts()
# Out:
# 0.0    1765
# 2.0    1095
# Name: trades, dtype: int64

# %%
data
# Out:
#                Close   returns  direction      lag1      lag2      lag3  \
# time
# 2010-01-08  1.441109  0.006478        1.0 -0.005989  0.002647 -0.004031
# 2010-01-11  1.451126  0.006927        1.0  0.006478 -0.005989  0.002647
# 2010-01-12  1.447660 -0.002391       -1.0  0.006927  0.006478 -0.005989
# 2010-01-13  1.452391  0.003262        1.0 -0.002391  0.006927  0.006478
# 2010-01-14  1.449990 -0.001654       -1.0  0.003262 -0.002391  0.006927
# ...              ...       ...        ...       ...       ...       ...
# 2020-12-25  1.218472 -0.000549       -1.0  0.000390 -0.004115  0.001699
# 2020-12-28  1.220510  0.001671        1.0 -0.000549  0.000390 -0.004115
# 2020-12-29  1.222345  0.001502        1.0  0.001671 -0.000549  0.000390
# 2020-12-30  1.225295  0.002411        1.0  0.001502  0.001671 -0.000549
# 2020-12-31  1.229990  0.003824        1.0  0.002411  0.001502  0.001671
#
#                 lag4      lag5  predict_diff  strategy  creturns  cstrategy  \
# time
# 2010-01-08  0.002363  0.004379           1.0  0.006478  1.006499   1.006499
# 2010-01-11 -0.004031  0.002363          -1.0 -0.006927  1.013495   0.999552
# 2010-01-12  0.002647 -0.004031          -1.0  0.002391  1.011075   1.001945
# 2010-01-13 -0.005989  0.002647           1.0  0.003262  1.014379   1.005219
# 2010-01-14  0.006478 -0.005989          -1.0  0.001654  1.012702   1.006883
# ...              ...       ...           ...       ...       ...        ...
# 2020-12-25 -0.003806  0.005161           1.0 -0.000549  0.851005   1.716040
# 2020-12-28  0.001699 -0.003806           1.0  0.001671  0.852428   1.718910
# 2020-12-29 -0.004115  0.001699           1.0  0.001502  0.853710   1.721494
# 2020-12-30  0.000390 -0.004115          -1.0 -0.002411  0.855771   1.717348
# 2020-12-31 -0.000549  0.000390          -1.0 -0.003824  0.859049   1.710794
#
#             trades
# time
# 2010-01-08     0.0
# 2010-01-11     2.0
# 2010-01-12     0.0
# 2010-01-13     2.0
# 2010-01-14     2.0
# ...            ...
# 2020-12-25     0.0
# 2020-12-28     0.0
# 2020-12-29     0.0
# 2020-12-30     2.0
# 2020-12-31     0.0
#
# [2860 rows x 13 columns]

# %% [markdown]
# Taking trading costs into consideration

# %%
ptc = 0.00007

# %%
data['strategy_net'] = data.strategy - data.trades * ptc

# %%
data['cstrategy_net'] = data.strategy_net.cumsum().apply(np.exp)

# %%
data
# Out:
#                Close   returns  direction      lag1      lag2      lag3  \
# time
# 2010-01-08  1.441109  0.006478        1.0 -0.005989  0.002647 -0.004031
# 2010-01-11  1.451126  0.006927        1.0  0.006478 -0.005989  0.002647
# 2010-01-12  1.447660 -0.002391       -1.0  0.006927  0.006478 -0.005989
# 2010-01-13  1.452391  0.003262        1.0 -0.002391  0.006927  0.006478
# 2010-01-14  1.449990 -0.001654       -1.0  0.003262 -0.002391  0.006927
# ...              ...       ...        ...       ...       ...       ...
# 2020-12-25  1.218472 -0.000549       -1.0  0.000390 -0.004115  0.001699
# 2020-12-28  1.220510  0.001671        1.0 -0.000549  0.000390 -0.004115
# 2020-12-29  1.222345  0.001502        1.0  0.001671 -0.000549  0.000390
# 2020-12-30  1.225295  0.002411        1.0  0.001502  0.001671 -0.000549
# 2020-12-31  1.229990  0.003824        1.0  0.002411  0.001502  0.001671
#
#                 lag4      lag5  predict_diff  strategy  creturns  cstrategy  \
# time
# 2010-01-08  0.002363  0.004379           1.0  0.006478  1.006499   1.006499
# 2010-01-11 -0.004031  0.002363          -1.0 -0.006927  1.013495   0.999552
# 2010-01-12  0.002647 -0.004031          -1.0  0.002391  1.011075   1.001945
# 2010-01-13 -0.005989  0.002647           1.0  0.003262  1.014379   1.005219
# 2010-01-14  0.006478 -0.005989          -1.0  0.001654  1.012702   1.006883
# ...              ...       ...           ...       ...       ...        ...
# 2020-12-25 -0.003806  0.005161           1.0 -0.000549  0.851005   1.716040
# 2020-12-28  0.001699 -0.003806           1.0  0.001671  0.852428   1.718910
# 2020-12-29 -0.004115  0.001699           1.0  0.001502  0.853710   1.721494
# 2020-12-30  0.000390 -0.004115          -1.0 -0.002411  0.855771   1.717348
# 2020-12-31 -0.000549  0.000390          -1.0 -0.003824  0.859049   1.710794
#
#             trades  strategy_net  cstrategy_net
# time
# 2010-01-08     0.0      0.006478       1.006499
# 2010-01-11     2.0     -0.007067       0.999412
# 2010-01-12     0.0      0.002391       1.001805
# 2010-01-13     2.0      0.003122       1.004937
# 2010-01-14     2.0      0.001514       1.006460
# ...            ...           ...            ...
# 2020-12-25     0.0     -0.000549       1.472349
# 2020-12-28     0.0      0.001671       1.474811
# 2020-12-29     0.0      0.001502       1.477029
# 2020-12-30     2.0     -0.002551       1.473266
# 2020-12-31     0.0     -0.003824       1.467643
#
# [2860 rows x 15 columns]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.creturns, name='Returns (Baseline)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy, name='Returns (Strategy)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy_net, name='Returns (Strategy + trading costs)'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %% [markdown]
# Evaluate risk and reward

# %%
data[['returns', 'strategy_net']].mean() * (252)
# Out:
# returns        -0.013387
# strategy_net    0.033805
# dtype: float64

# %%
data[['returns', 'strategy_net']].std() * np.sqrt(252)
# Out:
# returns         0.089179
# strategy_net    0.089101
# dtype: float64

# %% [markdown]
# Out-sample forward testing

# %%
data = pd.read_csv('../../resources/test_set.csv', parse_dates=['time'], index_col='time')

# %%
data
# Out:
#                Close
# time
# 2020-12-31  1.229990
# 2021-01-01  1.218027
# 2021-01-04  1.225070
# 2021-01-05  1.225160
# 2021-01-06  1.230027
# ...              ...
# 2021-12-27  1.132426
# 2021-12-28  1.133003
# 2021-12-29  1.131478
# 2021-12-30  1.136015
# 2021-12-31  1.132503
#
# [262 rows x 1 columns]

# %%
data['returns'] = np.log(data.div(data.shift(1)))

# %%
data['direction'] = np.sign(data.returns)

# %%
data
# Out:
#                Close   returns  direction
# time
# 2020-12-31  1.229990       NaN        NaN
# 2021-01-01  1.218027 -0.009774       -1.0
# 2021-01-04  1.225070  0.005766        1.0
# 2021-01-05  1.225160  0.000074        1.0
# 2021-01-06  1.230027  0.003965        1.0
# ...              ...       ...        ...
# 2021-12-27  1.132426 -0.000272       -1.0
# 2021-12-28  1.133003  0.000510        1.0
# 2021-12-29  1.131478 -0.001347       -1.0
# 2021-12-30  1.136015  0.004002        1.0
# 2021-12-31  1.132503 -0.003097       -1.0
#
# [262 rows x 3 columns]

# %%
lags = 5

# %%
cols = []

for lag in range(1, lags + 1):

  col = f"lag{lag}"
  data[col] = data.returns.shift(1)
  cols.append(col)

data.dropna(inplace=True)

# %%
data
# Out:
#                Close   returns  direction      lag1      lag2      lag3  \
# time
# 2021-01-04  1.225070  0.005766        1.0 -0.009774 -0.009774 -0.009774
# 2021-01-05  1.225160  0.000074        1.0  0.005766  0.005766  0.005766
# 2021-01-06  1.230027  0.003965        1.0  0.000074  0.000074  0.000074
# 2021-01-07  1.234111  0.003314        1.0  0.003965  0.003965  0.003965
# 2021-01-08  1.227144 -0.005661       -1.0  0.003314  0.003314  0.003314
# ...              ...       ...        ...       ...       ...       ...
# 2021-12-27  1.132426 -0.000272       -1.0 -0.000136 -0.000136 -0.000136
# 2021-12-28  1.133003  0.000510        1.0 -0.000272 -0.000272 -0.000272
# 2021-12-29  1.131478 -0.001347       -1.0  0.000510  0.000510  0.000510
# 2021-12-30  1.136015  0.004002        1.0 -0.001347 -0.001347 -0.001347
# 2021-12-31  1.132503 -0.003097       -1.0  0.004002  0.004002  0.004002
#
#                 lag4      lag5
# time
# 2021-01-04 -0.009774 -0.009774
# 2021-01-05  0.005766  0.005766
# 2021-01-06  0.000074  0.000074
# 2021-01-07  0.003965  0.003965
# 2021-01-08  0.003314  0.003314
# ...              ...       ...
# 2021-12-27 -0.000136 -0.000136
# 2021-12-28 -0.000272 -0.000272
# 2021-12-29  0.000510  0.000510
# 2021-12-30 -0.001347 -0.001347
# 2021-12-31  0.004002  0.004002
#
# [260 rows x 8 columns]

# %%
data['pred'] = LR.predict(X=data[cols])

# %%
data.pred.value_counts()
# Out:
#  1.0    151
# -1.0    109
# Name: pred, dtype: int64

# %%
hits = np.sign(data.direction * data.pred).value_counts()

# %%
hit_ratio = hits[1.0] / sum(hits)
hit_ratio
# Out:
# 0.5307692307692308

# %%
data['strategy'] = data.pred * data.returns

# %%
data['creturns'] = data['returns'].cumsum().apply(np.exp)
data['cstrategy'] = data['strategy'].cumsum().apply(np.exp)

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=data.index, y=data.creturns, name='Returns (Baseline)'))
fig.add_trace(go.Scatter(x=data.index, y=data.cstrategy, name='Returns (Strategy)'))

fig.update_layout(title='EUR/USD', xaxis_title='Time', yaxis_title='Price')

fig.show()

# %%
data['trades'] = data.pred.diff().fillna(0).abs()

# %%
data.trades.value_counts()
# Out:
# 2.0    135
# 0.0    125
# Name: trades, dtype: int64

# %%
data
# Out:
#                Close   returns  direction      lag1      lag2      lag3  \
# time
# 2021-01-04  1.225070  0.005766        1.0 -0.009774 -0.009774 -0.009774
# 2021-01-05  1.225160  0.000074        1.0  0.005766  0.005766  0.005766
# 2021-01-06  1.230027  0.003965        1.0  0.000074  0.000074  0.000074
# 2021-01-07  1.234111  0.003314        1.0  0.003965  0.003965  0.003965
# 2021-01-08  1.227144 -0.005661       -1.0  0.003314  0.003314  0.003314
# ...              ...       ...        ...       ...       ...       ...
# 2021-12-27  1.132426 -0.000272       -1.0 -0.000136 -0.000136 -0.000136
# 2021-12-28  1.133003  0.000510        1.0 -0.000272 -0.000272 -0.000272
# 2021-12-29  1.131478 -0.001347       -1.0  0.000510  0.000510  0.000510
# 2021-12-30  1.136015  0.004002        1.0 -0.001347 -0.001347 -0.001347
# 2021-12-31  1.132503 -0.003097       -1.0  0.004002  0.004002  0.004002
#
#                 lag4      lag5  pred  strategy  creturns  cstrategy  trades
# time
# 2021-01-04 -0.009774 -0.009774   1.0  0.005766  1.005782   1.005782     0.0
# 2021-01-05  0.005766  0.005766  -1.0 -0.000074  1.005856   1.005708     2.0
# 2021-01-06  0.000074  0.000074   1.0  0.003965  1.009852   1.009704     2.0
# 2021-01-07  0.003965  0.003965  -1.0 -0.003314  1.013205   1.006363     2.0
# 2021-01-08  0.003314  0.003314  -1.0  0.005661  1.007486   1.012076     0.0
# ...              ...       ...   ...       ...       ...        ...     ...
# 2021-12-27 -0.000136 -0.000136   1.0 -0.000272  0.929722   1.009369     2.0
# 2021-12-28 -0.000272 -0.000272   1.0  0.000510  0.930196   1.009884     0.0
# 2021-12-29  0.000510  0.000510  -1.0  0.001347  0.928943   1.011245     2.0
# 2021-12-30 -0.001347 -0.001347   1.0  0.004002  0.932668   1.015300     2.0
# 2021-12-31  0.004002  0.004002  -1.0  0.003097  0.929785   1.018449     2.0
#
# [260 rows x 13 columns]

# %% [markdown]
# Evaluate risk and return

# %%
data[['returns', 'strategy']].mean() * (252)
# Out:
# returns    -0.070562
# strategy    0.017719
# dtype: float64

# %%
data[['returns', 'strategy']].std() * np.sqrt(252)
# Out:
# returns     0.055419
# strategy    0.055587
# dtype: float64
